# %% [markdown]
# PANDAS

# %%
import pandas as pd
l1 = [1,2,3,4,5]
s1 = pd.Series(l1,index=['a','b','c','d','e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s1[0:2]
# Out:
# a    1
# b    2
# dtype: int64

# %%
l2 = {'a':10,'b':20,'c':30,'d':40,'e':50}
s2 = pd.Series(l2,index=['c','a','d','f','b','e']) # mengubah urutan index dictionary
s2
# Out:
# c    30.0
# a    10.0
# d    40.0
# f     NaN
# b    20.0
# e    50.0
# dtype: float64

# %%
s2[:3]
# Out:
# c    30.0
# a    10.0
# d    40.0
# dtype: float64

# %%
s1,s2
# Out:
# (a    1
#  b    2
#  c    3
#  d    4
#  e    5
#  dtype: int64,
#  c    30.0
#  a    10.0
#  d    40.0
#  f     NaN
#  b    20.0
#  e    50.0
#  dtype: float64)

# %%
s1+s2
# Out:
# a    11.0
# b    22.0
# c    33.0
# d    44.0
# e    55.0
# f     NaN
# dtype: float64

# %%
import pandas as pd
s3 = pd.DataFrame({'Nama':['ronaldo','messi','neymar'],'Umur':[39,37,35]},index=[1,2,3])
s3
# Out:
#       Nama  Umur
# 1  ronaldo    39
# 2    messi    37
# 3   neymar    35

# %%
data = pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 6)

# %% [markdown]
# `Index Location & Location`

# %%
data.iloc[0:4,0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 0   1            5.1           3.5
# 1   2            4.9           3.0
# 2   3            4.7           3.2
# 3   4            4.6           3.1

# %%
data.iloc[0:4,3:4]
# Out:
#    PetalLengthCm
# 0            1.4
# 1            1.4
# 2            1.3
# 3            1.5

# %%
data.loc[145:150,('SepalLengthCm','PetalLengthCm','Species')]
# Out:
#      SepalLengthCm  PetalLengthCm         Species
# 145            6.7            5.2  Iris-virginica
# 146            6.3            5.0  Iris-virginica
# 147            6.5            5.2  Iris-virginica
# 148            6.2            5.4  Iris-virginica
# 149            5.9            5.1  Iris-virginica

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# `Drop Data`

# %%
data.drop('Species',axis=1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
data.drop([1,2,3],axis=0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# `Minimum & Maximum`

# %%
data.min()
# Out:
# Id                         1
# SepalLengthCm            4.3
# SepalWidthCm             2.0
# PetalLengthCm            1.0
# PetalWidthCm             0.1
# Species          Iris-setosa
# dtype: object

# %%
data.max()
# Out:
# Id                          150
# SepalLengthCm               7.9
# SepalWidthCm                4.4
# PetalLengthCm               6.9
# PetalWidthCm                2.5
# Species          Iris-virginica
# dtype: object

# %% [markdown]
# `Pandas function`

# %%
data[['SepalLengthCm','SepalWidthCm']].head()
# Out:
#    SepalLengthCm  SepalWidthCm
# 0            5.1           3.5
# 1            4.9           3.0
# 2            4.7           3.2
# 3            4.6           3.1
# 4            5.0           3.6

# %%
def half(s):
  return s*0.5

# %%
def double(a):
  return a*2

# %%
x = data[['SepalLengthCm','SepalWidthCm']].apply(half)
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm
# 0           2.55          1.75
# 1           2.45          1.50
# 2           2.35          1.60
# 3           2.30          1.55
# 4           2.50          1.80

# %%
x = data[['SepalLengthCm','SepalWidthCm']].apply(double)
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm
# 0           10.2           7.0
# 1            9.8           6.0
# 2            9.4           6.4
# 3            9.2           6.2
# 4           10.0           7.2

# %% [markdown]
# `count and sort of values`

# %%
data.value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 1    5.1            3.5           1.4            0.2           Iris-setosa        1
# 95   5.6            2.7           4.2            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
#                                                                                  ..
# 51   7.0            3.2           4.7            1.4           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# ...

# %%
data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
x = data.sort_values(by='SepalLengthCm') #urutkan nilai berdasarkan SepalLengthCm
x.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 42  43            4.4           3.2            1.3           0.2  Iris-setosa
# 38  39            4.4           3.0            1.3           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 41  42            4.5           2.3            1.3           0.3  Iris-setosa
